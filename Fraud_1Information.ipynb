# %% [markdown]
# # IEEE-CIS Dolandırıcılık Tespiti

# %% [markdown]
# ![FRAUD](https://blog.ipleaders.in/wp-content/uploads/2019/05/fraud-696x434.jpg)

# %% [markdown]
# ## 1- GENEL BILGI
#
# Kredi ve banka kartı kullanarak yapılan alışveriş işlemlerinin hangileri gerçek sahipleri tarafından yapılan işlemler olduğunu hangilerinin ise dolandırıcılar tarafından yapılan sahtekarlık işlemleri olduğunu nasıl tespit edebiliriz ?
#
# Şu anda belki hantal olsa da, bu dolandırıcılık önleme sistemi tüketicilere yılda milyonlarca dolar tasarruf sağlıyor.
#
# IEEE Computational Intelligence Society (IEEE-CIS) ve ortağı Vesta Corporation daha yüksek doğrulukta sahtekarlık tespiti ile işlemlerin sorunsuz bir şekilde yerine getirilmesi için bağzı çalışmalar yapıyor.
#
# Bu yarışmada, Vesta'nın gerçek dünya e-ticaret işlemlerinden gelen datası kullanılmak suretiyle makine öğrenimi modellerini geliştirerek dolandırıcılık işlemlerini makineye yüksek düzeyde doğruluk oranıyla tahmin ettirmeye çalışacağız.

# %% [markdown]
# [2 - Data Aciklama](https://www.kaggle.com/ersinsen/fraud-2-data-aciklama/edit)

# %% [markdown]
# [3- KEŞIFSEL VERI ANALIZI (EDA)](https://www.kaggle.com/ersinsen/fraud-3-eda/execution)

# %% [markdown]
# [4- Veri Ön İşleme (Data Preprocessing)](https://www.kaggle.com/ersinsen/fraud-4-data-preprocessing/edit)

# %%
5- Modelleme

# %%
6-Karsilastirma
